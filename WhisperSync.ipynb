# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulRajaHub/Python-Improvements/blob/main/WhisperSync.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install git+https://github.com/openai/whisper.git
 # !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-n1nf_ltx
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-n1nf_ltx
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=764af4e9d94774454c1c695e7b6dccff6c7e37f00186bf55dca457191012aeda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l59icum0/wheels/c3/03/25/5e0ba78bc27a3a089f137c9f1d92fdfce16d06996c071a016c
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# ...

# %%
# !whisper "Pedro.mp3"
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/__init__.py:69: UserWarning: /root/.cache/whisper/large-v3-turbo.pt exists, but the SHA256 checksum does not match; re-downloading the file
#   warnings.warn(
# 100%|██████████████████████████████████████| 1.51G/1.51G [00:15<00:00, 103MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: English
# [00:00.000 --> 00:06.760]  I'm okay, I'm okay, a bit of a busy house, I guess you are as well.
# [00:06.760 --> 00:16.460]  I am, yes, I was just sort of putting my thoughts together and then just kind of syncing it up together so we can sort of have a good conversation.
# [00:16.460 --> 00:38.240]  Okay. So I had good sessions this week actually with Brian and aligning with him on several things, which is great because he's, I think we're in sync in how, you know, Anastas and Yang is approaching and how we need to work with them and work together.
# ...
